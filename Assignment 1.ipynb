# %% [raw]
# Ques 1.) In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [raw]
# In the given elements, the values are :
#
#     'hello' = This is a string value.
#     '-87.8' = This is a floating point value.
#     '6' = This is an integer value.
#
#  And The Expressions are :
#
#     '*' = This is the multiplication operator.
#     '-' = This is the subtraction operator.
#     '/' = this is the divison operator.
#     '+' = This is the addition operator.
#
# It is important to note that the operator listed above can be used
# as both expression & as part of larger expressions, depending on the
# context in which they are used.

# %% [raw]
# Ques 2.) What is the difference between string and variable?
#
#
# STRING - It is a data type in used to represent a sequence of
# charachter. It is enclosed in either single quotes ('') or
# double quotes(""). String can contain letters, numbers, symbols
# and whitespace. They are commonly used to store and manipulate
# textual data. For eg, 'hello', "Mohit", "546".
#
# VARIABLE - It is a named reference to a value stored in
# the computer's memory. It acts as a container for storing and
# accessing data. Variables are used to store different types of
# values, including strings. When you assign a value to a variable,
# you create a binding between the variable name and the value.
# Variable names in Python follow certain rules and conventions.
# For eg, name = 'John', age = 25.

# %% [raw]
# Ques 3.) Describe three different data types.
#
# Python supports various data types for representing different kinds of
# information. Here are three commonly used data types in Python:
#
# Integer (int): It represents whole numbers without decimal points. It can
# be positive or negative, including zero. For example: 5, -10, 0.
# Integers are used for counting, indexing, and performing arithmetic operations.
#
# String (str): It represents a sequence of characters enclosed in quotes ('' or "").
# Strings are used to store and manipulate textual data.
# For eg, "hello", 'Mohit', "678". You can perform various operations on
# strings, such as concatenation, slicing, and formatting.
#
# Floating-Point Number (float): It represents decimal numbers. It is used to
# store numbers with fractional parts. For eg, 3.14, -2.5, 0.0.
# Floating-point numbers are used in calculations that require precision or
# involve real-world measurements.

# %% [raw]
# Ques 4.) what is an expression made up of ? what do all expression do ?
#
# An expression is a combination of symbols, variables, constants, and operators
# that can be evaluated to produce a value. In programming and mathematics,
# expressions are used to represent computations and manipulate data.
#
# Expressions can take various forms depending on the programming or mathematical
# context.Here are some examples:
#
# Mathematical expression : 2 + 3 * 4 - (5 / 2)
# String concatenation expression : "Hey" + "Sudh"
# Logical expression : (x > 5) && (y <= 10)
# Function call expression : square(7)
#
# Expressions can perform different operations depending on the operators used.
# Common operators include arithmetic operators (such as +, -, *, /), logical operators
# (such as && for "and" and || for "or"), comparison operators (such as >, <, ==),
# and assignment operators (such as =).
#
# The primary purpose of expressions is to compute or evaluate a value. When an
# expression is evaluated, the operators and operands are processed according to the
# predefined rules of the programming language or mathematical system. The result of
# the evaluation can be used for further computations, assignments, or comparisons in
# a program.
#
# Expressions play a crucial role in programming because they allow you to perform
# calculations, make decisions, control program flow, and manipulate data. They enable
# you to write dynamic and responsive code that can adapt to changing conditions and
# input values.

# %% [raw]
# Ques 5.) This assignment statements, like spam = 10. What is the difference between an
# expression and a statement ?
#
# While expressions and statements are both fundamental elements of programming,
# there are key differences between them:
#
# Expression: An expression is a combination of symbols, variables, constants, and operators
# that can be evaluated to produce a value. Expressions always have a value and can be
# used as part of a larger expression or within a statement. Examples of expressions include
# "2 + 3", "x > 5", or "square(7)". The primary purpose of an expression is to compute a value.
#
# Statement: A statement is a complete unit of code that performs a specific action or
# operation. It represents a command or instruction to be executed. Unlike expressions,
# statements do not necessarily have a value, although they may produce side effects or
# affect the program's state. Examples of statements include assignment statements (e.g., "spam = 10"),
# conditional statements (e.g., "if-else"), loops (e.g., "for" or "while" loops), and
# function declarations.
#
# In simpler terms, expressions are used to compute values, while statements are used to
# perform actions or control the flow of a program. Expressions can be part of a statement,
# but a statement cannot be part of an expression. Statements are often composed of expressions
# and may use the results of expressions to perform their intended actions.
#
# In the assignment statement "spam = 10", the expression "10" evaluates to the value 10, and
# that value is assigned to the variable "spam". The statement itself does not have a value,
# but it changes the value associated with the variable "spam".

# %% [raw]
# Ques 6.) After running the following code, what does the variable bacon contain ?
# bacon = 22
# bacon + 1
#
# After running the given code, the variable "bacon" would still contain the value 22.
#
# Let's break down the code:
#
# 1.) bacon = 22: This line assigns the value 22 to the variable "bacon". After this line executes,
#     "bacon" holds the value 22.
#
# 2.) bacon + 1: This line is an expression that adds 1 to the value of "bacon" (which is 22).
#     However, this expression does not modify the value of "bacon" itself. It only evaluates
#     to the result of the addition, which is 23. If you want to update the value of "bacon" to
#     the result of this expression, you would need to assign it back to the variable,
#     like bacon = bacon + 1 or using the shorthand notation bacon += 1.
#
# Therefore, if you check the value of "bacon" after running the code snippet you provided, it would still be 22.

# %% [raw]
# Ques 7.) What should the values of the following two terms be ?
# 'spam' + 'spamspam'
# 'spam' *3
#
# The values of the two terms would be:
#
# 'spam' + 'spamspam': The result of this expression is the string 'spamspamspam'.
# Here, the + operator is used for string concatenation, which combines the two strings
# into a single string.
#
# 'spam' * 3: The result of this expression is the string 'spamspamspam'. Here, the * operator
# is used for string repetition. It repeats the string 'spam' three times, resulting
# in the string 'spamspamspam'.
#
# So, both expressions would yield the same value, which is the string 'spamspamspam'.

# %% [raw]
# Ques 8.) Why is eggs a valid variable name while 100 is invalid ?
#
# In most programming languages, including Python, variable names have certain rules and
# conventions that need to be followed. Here are some general rules for variable names :
#
# Variable names can consist of letters (both uppercase and lowercase), digits, and underscores (_).
# The first character of a variable name cannot be a digit. It should be a letter or an underscore.
# Variable names cannot be a reserved keyword or a predefined name in the programming language.
# Variable names are case-sensitive, so "eggs" and "Eggs" would be considered different variables.
# Based on these rules, let's consider or example :
#
# "eggs" is a valid variable name because it starts with a lowercase letter and contains only
# letters. It adheres to the rules and conventions for variable naming in most programming languages.
#
# "100" is an invalid variable name because it starts with a digit. Variable names cannot start
# with a number according to the naming rules.
#
# However, it's worth noting that in some programming languages, such as Python, variables can
# contain digits after the first character. For example, "spam100" would be a valid variable
# name in Python, as it starts with a letter and can contain digits and underscores after the first
# character. The key point is that the first character of a variable name cannot be a digit in most
# programming languages.

# %% [raw]
# Ques 9.) What three functions can be used to get the integer, floating-point number, or string
# version of a value ?
#
# In Python, the three functions commonly used to convert a value to a specific type are:
#
# 1.) int(): This function is used to convert a value to an integer. It takes a parameter and returns
#     the corresponding integer representation of that value. For example:
#
#     value = "10"
#     integer_value = int(value)
#
# 2.) float(): This function is used to convert a value to a floating-point number. It takes a
#     parameter and returns the corresponding floating-point representation of that value. For example:
#
#     value = "3.14"
#     float_value = float(value)
#
# 3.) str(): This function is used to convert a value to a string. It takes a parameter and returns
#     the string representation of that value. For example:
#
#     value = 42
#     string_value = str(value)
#
# These functions allow you to convert values between different data types, enabling you to perform
# operations or manipulations specific to each data type.

# %% [raw]
# Ques 10.) Why does this expression cause an error ? How can you fix it ?
# 'I have eaten' + 99 + 'burritos.'
#
# The expression 'I have eaten ' + 99 + ' burritos.' causes an error because it attempts to concatenate
# a string ('I have eaten ') with an integer (99) using the + operator. In Python, the + operator is used
# for concatenating strings, but it cannot directly concatenate a string with an integer.
#
# To fix this error, you need to ensure that all elements being concatenated are of the same data type.
# In this case, you can convert the integer 99 to a string using the str() function before concatenating
# it with the other strings. Here's the corrected code:
#
#    'I have eaten ' + str(99) + ' burritos.'
#
# By converting 99 to a string using str(99), you can concatenate all three elements as strings without
# causing an error. The expression will now produce the desired result:
#
#    'I have eaten 99 burritos.'
